# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gen = (5000,15000,50000)
mut = (10,27,793)
plt.figure(figsize=(5,3))
plt.plot(gen,mut,color='red',linewidth=4)
plt.xlabel('number of generations',fontsize=12)
plt.ylabel('number of mutations',fontsize=12)
plt.show()
